# %%
""" print(*range(1,20))
print(*range(15))

print(*range(1,100,2))

print(*range(20,0,-1))

for i in range(1,100):
    print(i) """

for i in range(1,20):
    print("*"*i)
# Out:
# *
# **
# ***
# ****
# *****
# ******
# *******
# ********
# *********
# **********
# ***********
# ************
# *************
# **************
# ***************
# ****************
# *****************
# ******************
# *******************
